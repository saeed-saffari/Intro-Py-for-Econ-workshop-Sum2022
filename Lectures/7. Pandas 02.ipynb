# %% [markdown]
# # <center> Pandas 02 <center>

# %% [markdown]
# <img src = 'https://github.com/saeed-saffari/alzahra-workshop-spr2021/blob/main/lecture/PIC/Pandas.png?raw=true'
#      width = "550"
#      >

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Na, NAN

# %%
df = pd.DataFrame({
    'col1':[1,2,3,4,np.nan],
    'col2':[np.nan,555,np.nan,444, 333],
    'col3':['abc', 'def', 'ghi', 'xyz', 'ghj'],
    'col4':['16', '23', '18', '25', '27'],
    'col5':['187', '160', np.nan, '202', '163']
})
df
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0    NaN  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0    NaN  ghi   18  NaN
# 3   4.0  444.0  xyz   25  202
# 4   NaN  333.0  ghj   27  163

# %%
df.isnull()
# Out:
#     col1   col2   col3   col4   col5
# 0  False   True  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False   True
# 3  False  False  False  False  False
# 4   True  False  False  False  False

# %%
df.isna()
# Out:
#     col1   col2   col3   col4   col5
# 0  False   True  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False   True
# 3  False  False  False  False  False
# 4   True  False  False  False  False

# %%
df.dropna()
# Out:
#    col1   col2 col3 col4 col5
# 1   2.0  555.0  def   23  160
# 3   4.0  444.0  xyz   25  202

# %%
df
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0    NaN  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0    NaN  ghi   18  NaN
# 3   4.0  444.0  xyz   25  202
# 4   NaN  333.0  ghj   27  163

# %%
df.fillna(120)
# Out:
#     col1   col2 col3 col4 col5
# 0    1.0  120.0  abc   16  187
# 1    2.0  555.0  def   23  160
# 2    3.0  120.0  ghi   18  120
# 3    4.0  444.0  xyz   25  202
# 4  120.0  333.0  ghj   27  163

# %%
df.fillna('missing')
# Out:
#       col1     col2 col3 col4     col5
# 0      1.0  missing  abc   16      187
# 1      2.0    555.0  def   23      160
# 2      3.0  missing  ghi   18  missing
# 3      4.0    444.0  xyz   25      202
# 4  missing    333.0  ghj   27      163

# %%
df
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0    NaN  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0    NaN  ghi   18  NaN
# 3   4.0  444.0  xyz   25  202
# 4   NaN  333.0  ghj   27  163

# %%
df.fillna(method='ffill')
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0    NaN  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0  555.0  ghi   18  160
# 3   4.0  444.0  xyz   25  202
# 4   4.0  333.0  ghj   27  163

# %%
df.fillna(method='ffill').dropna()
# Out:
#    col1   col2 col3 col4 col5
# 1   2.0  555.0  def   23  160
# 2   3.0  555.0  ghi   18  160
# 3   4.0  444.0  xyz   25  202
# 4   4.0  333.0  ghj   27  163

# %%
df.fillna(method='bfill')
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0  555.0  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0  444.0  ghi   18  202
# 3   4.0  444.0  xyz   25  202
# 4   NaN  333.0  ghj   27  163

# %%
df.interpolate()
# Out:
#    col1   col2 col3 col4 col5
# 0   1.0    NaN  abc   16  187
# 1   2.0  555.0  def   23  160
# 2   3.0  499.5  ghi   18  NaN
# 3   4.0  444.0  xyz   25  202
# 4   4.0  333.0  ghj   27  163

# %%
df[['col4','col5']] = df[['col4','col5']].astype(float)

# %%
df
# Out:
#    col1   col2 col3  col4   col5
# 0   1.0    NaN  abc  16.0  187.0
# 1   2.0  555.0  def  23.0  160.0
# 2   3.0    NaN  ghi  18.0    NaN
# 3   4.0  444.0  xyz  25.0  202.0
# 4   NaN  333.0  ghj  27.0  163.0

# %%
df.interpolate()
# Out:
#    col1   col2 col3  col4   col5
# 0   1.0    NaN  abc  16.0  187.0
# 1   2.0  555.0  def  23.0  160.0
# 2   3.0  499.5  ghi  18.0  181.0
# 3   4.0  444.0  xyz  25.0  202.0
# 4   4.0  333.0  ghj  27.0  163.0

# %% [markdown]
# ## Concat

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']},
    index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']},
    index=[4, 5, 6, 7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1, df2], axis = 0)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
df3 = pd.DataFrame({
    'E': ['E0', 'E1', 'E2', 'E3'],
    'F': ['F0', 'F1', 'F2', 'F3'],
    'G': ['G0', 'G1', 'G2', 'G3'],
    'H': ['H0', 'H1', 'H2', 'H3']},
    index=[0, 1, 2, 3])
df3
# Out:
#     E   F   G   H
# 0  E0  F0  G0  H0
# 1  E1  F1  G1  H1
# 2  E2  F2  G2  H2
# 3  E3  F3  G3  H3

# %%
pd.concat([df1,df3], axis=1)
# Out:
#     A   B   C   D   E   F   G   H
# 0  A0  B0  C0  D0  E0  F0  G0  H0
# 1  A1  B1  C1  D1  E1  F1  G1  H1
# 2  A2  B2  C2  D2  E2  F2  G2  H2
# 3  A3  B3  C3  D3  E3  F3  G3  H3

# %% [markdown]
# ## Merge

# %%
left = pd.DataFrame({
    'key': ['k0', 'k1', 'k2', 'k3'],
    'A'  : ['A0', 'A1', 'A2', 'A3'],
    'B'  : ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({
    'key': ['k0', 'k1', 'k2', 'k4'],
    'C'  : ['C0', 'C1', 'C2', 'C4'],
    'D'  : ['D0', 'D1', 'D2', 'D4']})

# %%
left
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k1  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  k0  C0  D0
# 1  k1  C1  D1
# 2  k2  C2  D2
# 3  k4  C4  D4

# %%
pd.merge(left, right, how='inner', on = 'key')
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on = 'key')
# Out:
#   key    A    B    C    D
# 0  k0   A0   B0   C0   D0
# 1  k1   A1   B1   C1   D1
# 2  k2   A2   B2   C2   D2
# 3  k3   A3   B3  NaN  NaN
# 4  k4  NaN  NaN   C4   D4

# %%
pd.merge(left, right, how='left', on = 'key')
# Out:
#   key   A   B    C    D
# 0  k0  A0  B0   C0   D0
# 1  k1  A1  B1   C1   D1
# 2  k2  A2  B2   C2   D2
# 3  k3  A3  B3  NaN  NaN

# %%
pd.merge(left, right, how='right', on = 'key')
# Out:
#   key    A    B   C   D
# 0  k0   A0   B0  C0  D0
# 1  k1   A1   B1  C1  D1
# 2  k2   A2   B2  C2  D2
# 3  k4  NaN  NaN  C4  D4

# %% [markdown]
# ## Group by

# %%
data = {
    'Company': ['GOOG', 'GOOG','GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
    'Person' : ['Sam', 'Charlie', 'John', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
    'Sales'  : [200, 120, 236, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    GOOG     John    236
# 3    MSFT      Amy    340
# 4    MSFT  Vanessa    124
# 5      FB     Carl    243
# 6      FB    Sarah    350

# %%
by_comp = df.groupby('Company')
by_comp

# %%
by_comp.mean()
# Out:
#               Sales
# Company
# FB       296.500000
# GOOG     185.333333
# MSFT     232.000000

# %%
by_comp.mean().plot(kind = 'bar', color = 'red')
# Out:
# <AxesSubplot:xlabel='Company'>

# %%
by_comp.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      59.374518
# MSFT     152.735065

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    236
# MSFT     Vanessa    340

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          3      3
# MSFT          2      2

# %%
by_comp.agg(['count', 'max', 'min'])
# Out:
#         Person                   Sales
#          count      max      min count  max  min
# Company
# FB           2    Sarah     Carl     2  350  243
# GOOG         3      Sam  Charlie     3  236  120
# MSFT         2  Vanessa      Amy     2  340  124

# %%
by_comp.get_group('GOOG')
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    GOOG     John    236

# %%
by_comp.describe()
# Out:
#         Sales
#         count        mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.500000   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      3.0  185.333333   59.374518  120.0  160.00  200.0  218.00  236.0
# MSFT      2.0  232.000000  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().columns
# Out:
# MultiIndex([('Sales', 'count'),
#             ('Sales',  'mean'),
#             ('Sales',   'std'),
#             ('Sales',   'min'),
#             ('Sales',   '25%'),
#             ('Sales',   '50%'),
#             ('Sales',   '75%'),
#             ('Sales',   'max')],
#            )

# %%
by_comp.describe()['Sales']
# Out:
#          count        mean         std    min     25%    50%     75%    max
# Company
# FB         2.0  296.500000   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG       3.0  185.333333   59.374518  120.0  160.00  200.0  218.00  236.0
# MSFT       2.0  232.000000  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe()['Sales'][['max','min']]
# Out:
#            max    min
# Company
# FB       350.0  243.0
# GOOG     236.0  120.0
# MSFT     340.0  124.0

# %%
x = by_comp.describe()['Sales'][['max','min']]
x
# Out:
#            max    min
# Company
# FB       350.0  243.0
# GOOG     236.0  120.0
# MSFT     340.0  124.0

# %%
by_comp.describe()['Sales']['max'].max()
# Out:
# 350.0

# %%
x['diffrence'] = x['max'] - x['min']
x
# Out:
#            max    min  diffrence
# Company
# FB       350.0  243.0      107.0
# GOOG     236.0  120.0      116.0
# MSFT     340.0  124.0      216.0

# %% [markdown]
# ## Exercise

# %% [markdown]
# link: [link to download data (2019)](https://insights.stackoverflow.com/survey)

# %%
df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Switzerland', 'Argentina',
#        'Sri Lanka', 'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh',
#        'Spain', 'Serbia', 'Poland', 'Sweden', 'China', 'France',
#        'Netherlands', 'Italy', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates', 'Portugal',
#        'Nigeria', 'Norway', 'Nicaragua', 'Zimbabwe', 'Egypt', 'Mexico',
#        'Dominican Republic', 'Guatemala', 'Chile', 'Ecuador', 'Ghana',
#        'Uganda', 'Cambodia', 'Mauritius', 'Nepal', 'Singapore',
#        'Sierra Leone', 'Republic of Moldova', 'Belgium', 'Armenia',
#        'Afghanistan', 'Bahrain', 'Mongolia', 'Georgia', 'Cyprus', 'Kenya',
#        'Luxembourg', 'Saudi Arabia', 'Cape Verde', 'Peru', 'Burundi',
#        'Iraq', 'Slovakia', 'Algeria', 'Taiwan', 'Yemen', 'Indonesia',
#        'Morocco', 'Libyan Arab Jamahiriya', 'Belize', 'Mali',
#        'Trinidad and Tobago', 'Venezuela, Bolivarian Republic of...',
#        'Panama', 'Lebanon', 'Tunisia', 'Kuwait', 'Andorra',
#        "Côte d'Ivoire", 'Syrian Arab Republic', 'El Salvador', 'Cameroon',
#        'Malta', 'Turkmenistan', 'Brunei Darussalam',
#        'Other Country (Not Listed Above)', 'Costa Rica', 'Jordan',
#        'Albania', 'Uzbekistan', 'Sudan', 'Kazakhstan',
#        'The former Yugoslav Republic of Macedonia', 'Ethiopia',
#        'Paraguay', 'Myanmar', 'Somalia', 'Guyana', 'Honduras', 'Qatar',
#        'Jamaica', 'Fiji', 'Haiti', 'Democratic Republic of the Congo',
#        'Benin', 'Namibia', 'Montenegro', 'Rwanda', 'Tajikistan',
#        'Uruguay', 'Mauritania', 'Bolivia', 'Gabon', 'Liechtenstein',
#        'United Republic of Tanzania', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Madagascar', 'Guinea',
#        'Republic of Korea', 'Cuba', 'Maldives', 'Monaco', 'North Korea',
#        'Senegal', 'Angola', 'Iceland', 'Togo', 'Swaziland',
#        'Congo, Republic of the...', 'Zambia', 'Oman', 'Timor-Leste',
#        'Tonga', 'Djibouti', "Democratic People's Republic of Korea",
#        'Niger', 'Mozambique', 'Botswana', 'Dominica', 'Papua New Guinea',
#        'Barbados', 'Seychelles', 'Lesotho', 'Bahamas', 'Burkina Faso',
#        'Saint Kitts and Nevis', 'Malawi', 'Liberia', 'Bhutan',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Chad', nan], dtype=object)

# %%
df.Country.value_counts()#.sort_values(ascending=False)
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
coutry_grp = df.groupby('Country')
coutry_grp

# %%
coutry_grp.get_group('Iran').head()
# Out:
#      Respondent                      MainBranch Hobbyist  \
# 161         163  I am a developer by profession       No
# 443         445  I am a developer by profession       No
# 565         568  I am a developer by profession       No
# 612         615  I am a developer by profession      Yes
# 616         619  I am a developer by profession      Yes
#
#                                            OpenSourcer  \
# 161                                              Never
# 443  Less than once a month but more than once per ...
# 565                            Less than once per year
# 612                                              Never
# 616                                              Never
#
#                                             OpenSource  \
# 161  OSS is, on average, of LOWER quality than prop...
# 443  OSS is, on average, of HIGHER quality than pro...
# 565  The quality of OSS and closed source software ...
# 612  OSS is, on average, of HIGHER quality than pro...
# 616  OSS is, on average, of HIGHER quality than pro...
#
#                                             Employment Country Student  \
# 161                                 Employed full-time    Iran      No
# 443                                 Employed full-time    Iran      No
# 565  Independent contractor, freelancer, or self-em...    Iran      No
# 612                                 Employed full-time    Iran      No
# 616                                 Employed full-time    Iran      No
#
#                                          EdLevel  \
# 161     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 443     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 565     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 612  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 616     Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                         UndergradMajor  ...  \
# 161  Computer science, computer engineering, or sof...  ...
# 443  Computer science, computer engineering, or sof...  ...
# 565  Information systems, information technology, o...  ...
# 612  Computer science, computer engineering, or sof...  ...
# 616  Computer science, computer engineering, or sof...  ...
#
#                                 WelcomeChange  \
# 161                                       NaN
# 443  Somewhat more welcome now than last year
# 565  Somewhat more welcome now than last year
# 612     A lot more welcome now than last year
# 616  Somewhat more welcome now than last year
#
#                                           SONewContent   Age Gender Trans  \
# 161  Industry news about technologies you're intere...  32.0  Woman    No
# 443  Tech articles written by other developers;Indu...  31.0  Woman    No
# 565       Courses on technologies you're interested in  22.0    Man    No
# 612  Tech articles written by other developers;Indu...  29.0    Man    No
# 616  Tech articles written by other developers;Indu...  22.0    Man    No
#
#                    Sexuality       Ethnicity Dependents SurveyLength  \
# 161  Straight / Heterosexual  Middle Eastern        Yes     Too long
# 443                      NaN     South Asian        Yes     Too long
# 565  Straight / Heterosexual  Middle Eastern         No     Too long
# 612  Straight / Heterosexual  Middle Eastern         No     Too long
# 616  Straight / Heterosexual  Middle Eastern        Yes     Too long
#
#                      SurveyEase
# 161                   Difficult
# 443                        Easy
# 565  Neither easy nor difficult
# 612  Neither easy nor difficult
# 616                        Easy
#
# [5 rows x 85 columns]

# %%
df.Country == 'Iran'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
df[df.Country == 'Iran']['SocialMedia'].unique()
# Out:
# array(['Instagram', 'WhatsApp', nan, 'Twitter', 'YouTube', 'Reddit',
#        'LinkedIn', 'Facebook', "I don't use social media"], dtype=object)

# %%
df[df.Country == 'Iran']['SocialMedia'].value_counts()
# Out:
# Instagram                   174
# Twitter                     115
# YouTube                      86
# LinkedIn                     61
# WhatsApp                     56
# I don't use social media     25
# Reddit                       12
# Facebook                      9
# Name: SocialMedia, dtype: int64

# %%
coutry_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_respon = df['Country'].value_counts()
country_respon
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
df[df.Country == 'Iran']['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 268
